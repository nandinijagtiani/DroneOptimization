# %%
import sys
import numpy as np

from gamspy import (
    Container,Set,Alias,Parameter,Variable,Equation,Model,Problem,Sense,Options,
    Domain,Number,Sum,Product,Smax,Smin,Ord,Card,SpecialValues,
)

m = Container()

# %%
# YOU NEED TO UPDATE NODES and ARCS here
i = Set(m,'i',records= ['store', 'trash'] + [f't{i}' for i in range(1, 11)] + [f"h{i}" for i in range(1, 11)])

z = Alias(m,'z',i)
j = Alias(m,'j',i)
k = Alias(m,'k',i)

t = Set(m,'t',domain=i, records = [f't{i}' for i in range(1, 11)])

h = Set(m,'h',domain=i, records = [f'h{i}' for i in range(1, 11)])

d = Parameter(m,'d', domain=t, domain_forwarding = True,
    records=[ ('t1', 50), ('t2', 60), ('t3', 80), ('t4', 70), 
        ('t5', 50), ('t6', 60), ('t7', 90), ('t8', 80), ('t9', 50), ('t10', 100) ])
alpha = Parameter(m,'alpha', records=200)
beta = Parameter(m,'beta', records=75)
gamma = Parameter(m,'gamma', records=25)
p = Parameter(m,'p', records=4)
q = Parameter(m,'q', records=2)

arcs = Set(m, 'arcs', domain=[i, i])
arcs['store', t] = True
arcs[t, h].where[Ord(t) == Ord(h)] = True
arcs[h, t].where[Ord(h) == Ord(t) - p] = True
arcs[h, t].where[Ord(h) == Ord(t) - q] = True
arcs[h, 'trash'] = True
arcs['store', 'trash'] = True
display(arcs.pivot())
# Out:
# /home/samjenkins2001/CS524/venv/lib/python3.10/site-packages/gams/transfer/syms/_mixins/pivot.py:121: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.fillna(fill_value, inplace=True)
#        trash     t1     t2     t3     t4     t5     t6     t7     t8     t9  \
# store   True   True   True   True   True   True   True   True   True   True
# t1     False  False  False  False  False  False  False  False  False  False
# t2     False  False  False  False  False  False  False  False  False  False
# t3     False  False  False  False  False  False  False  False  False  False
# t4     False  False  False  False  False  False  False  False  False  False
# t5     False  False  False  False  False  False  False  False  False  False
# t6     False  False  False  False  False  False  False  False  False  False
# t7     False  False  False  False  False  False  False  False  False  False
# t8     False  False  False  False  False  False  False  False  False  False
# t9     False  False  False  False  False  False  False  False  False  False
# t10    False  False  False  False  False  False  False  False  False  False
# h1      True  False  False   True  False   True  False  False  False  False
# h2      True  False  False  False   True  False   True  False  False  False
# h3      True  False  False  False  False   True  False   True  False  False
# h4      True  False  False  False  False  False   True  False   True  False
# h5      True  False  False  False  False  False  False   True  False   True
# h6      True  False  False  False  False  False  False  False   True  False
# h7      True  False  False  False  False  False  False  False  False   True
# h8      True  False  False  False  False  False  False  False  False  False
# h9      True  False  False  False  False  False  False  False  False  False
# h10     True  False  False  False  False  False  False  False  False  False
#
#        ...     h1     h2     h3     h4     h5     h6     h7     h8     h9  \
# store  ...  False  False  False  False  False  False  False  False  False
# t1     ...   True  False  False  False  False  False  False  False  False
# t2     ...  False   True  False  False  False  False  False  False  False
# t3     ...  False  False   True  False  False  False  False  False  False
# t4     ...  False  False  False   True  False  False  False  False  False
# t5     ...  False  False  False  False   True  False  False  False  False
# t6     ...  False  False  False  False  False   True  False  False  False
# t7     ...  False  False  False  False  False  False   True  False  False
# t8     ...  False  False  False  False  False  False  False   True  False
# t9     ...  False  False  False  False  False  False  False  False   True
# t10    ...  False  False  False  False  False  False  False  False  False
# h1     ...  False  False  False  False  False  False  False  False  False
# h2     ...  False  False  False  False  False  False  False  False  False
# h3     ...  False  False  False  False  False  False  False  False  False
# h4     ...  False  False  False  False  False  False  False  False  False
# h5     ...  False  False  False  False  False  False  False  False  False
# h6     ...  False  False  False  False  False  False  False  False  False
# h7     ...  False  False  False  False  False  False  False  False  False
# h8     ...  False  False  False  False  False  False  False  False  False
# h9     ...  False  False  False  False  False  False  False  False  False
# h10    ...  False  False  False  False  False  False  False  False  False
#
#          h10
# store  False
# t1     False
# t2     False
# t3     False
# t4     False
# t5     False
# t6     False
# t7     False
# t8     False
# t9     False
# t10     True
# h1     False
# h2     False
# h3     False
# h4     False
# h5     False
# h6     False
# h7     False
# h8     False
# h9     False
# h10    False
#
# [21 rows x 21 columns]

# %%
# put your code here
b = Parameter(m,"b",domain=i)
for a in range(1, 11):
    b[f't{a}'] = -d[f't{a}']
    b[f'h{a}'] = d[f't{a}']
b['store'] = 5000
b['trash'] = -5000

c = Parameter(m, 'c', domain=[i,i])
c['store', t] = alpha
for y in range(1, 9):
    c[f'h{y}', f't{y+2}'] = beta
for y in range(1, 7):
    c[f'h{y}', f't{y+4}'] = gamma

x = Variable(m, "x", "positive", domain=[i,i])

balance = Equation(m, 'balance', domain=i)
balance[z] = Sum(arcs[z,j], x[z,j]) - Sum(arcs[k,z], x[k,z]) == b[z]

Malfoy = Model(m,
    name="Malfoy",
    equations=m.getEquations(),
    problem=Problem.LP,
    sense=Sense.MIN,
    objective=Sum(arcs[i,z], c[i,z]*x[i,z]),
)

Malfoy.solve()
# Out:
#   Solver Status   Model Status Objective Num of Equations Num of Variables  \
# 0        Normal  OptimalGlobal     66750               23               46
#
#   Model Type Solver Solver Time
# 0         LP  CPLEX       0.001

# %%
Cost = Parameter(m,'Cost')
Cost[:] = Malfoy.objective_value

NumEqu= Parameter(m,'NumEqu')
NumEqu[:] = Malfoy.num_equations

NumBought= Parameter(m,'NumBought')
# following may need update if your variables are different
NumBought[:] = Sum(t, x.l['store',t])

print(f"Cost = {Cost.toValue()}")
print(f"NumEqu = {NumEqu.toValue()}")
print(f"NumBought = {NumBought.toValue()}")
# Out:
# Cost = 66750.0
# NumEqu = 23.0
# NumBought = 260.0
